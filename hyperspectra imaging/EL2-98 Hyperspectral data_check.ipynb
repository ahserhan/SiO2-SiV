# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm

# %%
def findarg(data, value):
    arg = 0
    for wl in data:
        if wl<value:
            arg = arg + 1
        else:
            return arg
        
    return arg

# %%
data = pd.read_pickle('asher_20230603_hyperspec_EL2_98.pkl')
im = data['im']
wavel = data['wavelength']
map = np.sum(im, axis = 2)
# pixel numbers x and y
px = len(im)
py = len(im[0])
intensity = np.zeros((px,py))
#total intensity plot
plt.imshow(map, cmap='viridis')
plt.colorbar()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# ### log scale plot

# %%
plt.figure(figsize=(12,9))
plt.imshow(map, cmap='viridis', norm =LogNorm())
plt.colorbar()
plt.show()

# %%
regionx, regiony = 20,27

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
regionx, regiony = 36,11

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
regionx, regiony = 36,16

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 36,10

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 13,20

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 0,0

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 39,0

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 35,10

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 35,5

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 17,6
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 35,23
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
regionx, regiony = 33,5
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
regionx, regiony = 33,5
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
regionx, regiony = 15,17
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])
