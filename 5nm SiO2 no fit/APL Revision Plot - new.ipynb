# %%
import numpy as np 
import matplotlib.pyplot as plt 
import uncertainties as unc
import pandas as pd
import uncertainties.unumpy as unp
from matplotlib import cm
import matplotlib.colors as col
from lmfit.models import ExponentialModel, GaussianModel
from matplotlib import cm

data10keV = pd.read_csv('data10keV.csv')
data30keV = pd.read_csv('data30keV.csv')
data50keV = pd.read_csv('data50keV.csv')
data70keV = pd.read_csv('data70keV.csv')
data90keV = pd.read_csv('data90keV.csv')
fine10keV = pd.read_csv('fine10keV.csv')
fine30keV = pd.read_csv('fine30keV.csv')
fine50keV = pd.read_csv('fine50keV.csv')
fine70keV = pd.read_csv('fine70keV.csv')
fine90keV = pd.read_csv('fine90keV.csv')

# %%
def plot3dVacancy(DEPTH,data,thickness,lab, ax,c):

    ax.plot(DEPTH,data,  linestyle = '--', lw = 3, color = c)
    # else:
    #     # plt.scatter(DEPTH, data, zs=thickness, zdir='y', marker = '.', label = 'Carbon Vacancy Distribution Data', color = 'k', s = 1)
    #     ax.plot(fit_x, fitcurve,  linestyle = '--', label = 'Carbon Vacancy Distribution', lw = 3)
    
    # ax.fill_between(DEPTH, 0, data, step='mid', alpha=0.1)

# %%
def plot3dSilicon(DEPTH,data,thickness,c, ax):
        ax.plot(DEPTH, data, lw = 2, color = c)
        # ax.plot(DEPTH, data, lw = 2.5, color = 'aqua')

# %%
def plot3dSilicon1(DEPTH,data,thickness,c):
        plt.plot(DEPTH, data, lw = 2, color = c, label = thickness)
        plt.yscale('log')
        # plt.plot(DEPTH, data, lw = 2, color = 'aqua')

# %%
def plot3dGallium(depth,data,thickness,c,ax):

    ax.plot(depth, data, lw = 3, color = c, linestyle = '-.',label = str(thickness)+' keV')
    # plt.plot(fit_x, fitcurve, lw = 1, color = 'k', label = 'Gallium Ion Distribution')

    # if lab == 0:
    #     plt.plot(depth, data, lw = 1, color = 'k')
    # else:
    #     plt.plot(depth, data, lw = 1, color = 'k', label = 'Gallium Ion Distribution')

# %%
# cmap = cm.viridis  # color for silicon
cmap = cm.autumn
colors = [cmap(i / 5) for i in range(5)]

# cmap = sns.color_palette("ch:start=.2,rot=-.3", as_cmap=True)
cmap = cm.bone
colors2 = [cmap(i / 5) for i in range(5)]

# cmap = sns.color_palette("flare", as_cmap=True) # color for vacancy
cmap = cm.winter
colors3 = [cmap(i / 5) for i in range(5)]

# %%
plt.rcParams.update({'font.size': 20})
cm = 1/2.54 
fig, axs = plt.subplots(2,1,figsize=(20*cm, 20*cm), sharex=True, gridspec_kw={'height_ratios': [4, 5]})
# fig, axs = plt.subplots(2,1,figsize=(5,5), sharex=True, gridspec_kw={'height_ratios': [4, 5]})
axs[0].grid()
# axs[0].set_xlim(0, 80)
# axs[0].set_xlabel('Depth in Diamond (nm)')
# axs[0].set_ylabel('Density per Dose ($cm^{-3}$/$cm^{-2}$)')
# fig.text(0.0, 0.5, 'Density per Dose ($cm^{-3}$/$cm^{-2}$)', va='center', rotation='vertical')

plot3dSilicon(fine10keV['DEPTH'],fine10keV['Si'], 10, colors[4], axs[0])
plot3dSilicon(fine30keV['DEPTH'],fine30keV['Si'], 30,colors[3], axs[0])
plot3dSilicon(fine50keV['DEPTH'],fine50keV['Si'],50,colors[2], axs[0])
plot3dSilicon(fine70keV['DEPTH'],fine70keV['Si'], 70,colors[1], axs[0])
plot3dSilicon(fine90keV['DEPTH'],fine90keV['Si'], 90,colors[0], axs[0])

# plot3dSilicon(fine10keV['DEPTH'],fine10keV['Si'], 10, 'C0', axs[0])
# plot3dSilicon(fine30keV['DEPTH'],fine30keV['Si'], 30,'C1', axs[0])
# plot3dSilicon(fine50keV['DEPTH'],fine50keV['Si'],50,'C2', axs[0])
# plot3dSilicon(fine70keV['DEPTH'],fine70keV['Si'], 70,'C3', axs[0])
# plot3dSilicon(fine90keV['DEPTH'],fine90keV['Si'], 90,'C4', axs[0]) 


plot3dVacancy(data10keV['DEPTH'][0:],data10keV['C'][0:]*1e8, 10,1, axs[0], colors3[4])
plot3dVacancy(data30keV['DEPTH'],data30keV['C']*1e8, 30,0, axs[0], colors3[3])
plot3dVacancy(data50keV['DEPTH'][1:],data50keV['C'][1:]*1e8,50,0, axs[0], colors3[2])
plot3dVacancy(data70keV['DEPTH'][3:],data70keV['C'][3:]*1e8, 70,0, axs[0], colors3[1])
plot3dVacancy(data90keV['DEPTH'][1:],data90keV['C'][1:]*1e8, 90,0, axs[0], colors3[0])

# plot3dVacancy(data10keV['DEPTH'][0:],data10keV['C'][0:]*1e8, 10,1, axs[0])
# plot3dVacancy(data30keV['DEPTH'],data30keV['C']*1e8, 30,0, axs[0])
# plot3dVacancy(data50keV['DEPTH'][0:],data50keV['C'][0:]*1e8,50,0, axs[0])
# plot3dVacancy(data70keV['DEPTH'][0:],data70keV['C'][0:]*1e8, 70,0, axs[0])
# plot3dVacancy(data90keV['DEPTH'][0:],data90keV['C'][0:]*1e8, 90,0, axs[0])

# axs[0].plot([],[],lw = 2, color = 'aqua', label = 'Si')
# axs[0].plot([],[],lw = 2, color = 'C0', linestyle = '--',label = 'V')
# axs[0].plot([],[],lw = 2, color = 'k', linestyle = '-.',label = 'Ga$^+$')
# axs[0].legend()

axs[1].grid()
axs[1].set_xlim(0, 60)
axs[1].set_ylim(0, 2.4e6)
axs[1].set_xlabel('Depth in Diamond (nm)')
# axs[1].set_ylabel('Density per Dose ($cm^{-3}$/$cm^{-2}$)')

# plot3dVacancy(data10keV['DEPTH'][1:],data10keV['C'][1:]*1e8, 10,1, axs[1])
# plot3dVacancy(data30keV['DEPTH'],data30keV['C']*1e8, 30,0, axs[1])
# plot3dVacancy(data50keV['DEPTH'][4:],data50keV['C'][4:]*1e8,50,0, axs[1])
# plot3dVacancy(data70keV['DEPTH'][1:],data70keV['C'][1:]*1e8, 70,0, axs[1])
# plot3dVacancy(data90keV['DEPTH'][2:],data90keV['C'][2:]*1e8, 90,0, axs[1])

plot3dSilicon(fine10keV['DEPTH'],fine10keV['Si'], 10, colors[4], axs[1])
plot3dSilicon(fine30keV['DEPTH'],fine30keV['Si'], 30,colors[3], axs[1])
plot3dSilicon(fine50keV['DEPTH'],fine50keV['Si'],50,colors[2], axs[1])
plot3dSilicon(fine70keV['DEPTH'],fine70keV['Si'], 70,colors[1], axs[1])
plot3dSilicon(fine90keV['DEPTH'],fine90keV['Si'], 90,colors[0], axs[1])

plot3dGallium(data10keV['DEPTH'],data10keV['Ga'], 10,colors2[4], axs[1])
plot3dGallium(data30keV['DEPTH'],data30keV['Ga'], 30,colors2[3], axs[1])
plot3dGallium(data50keV['DEPTH'],data50keV['Ga'],50,colors2[2], axs[1])
plot3dGallium(data70keV['DEPTH'],data70keV['Ga'], 70,colors2[1], axs[1])
plot3dGallium(data90keV['DEPTH'],data90keV['Ga'], 90,colors2[0], axs[1])

# axs[1].legend()
fig.tight_layout()


fig.savefig('fffffffff.pdf', format= 'pdf')

# %%
# Create a 7x3 colormap with each column representing a different color
combined_colors = [colors3, colors, colors2]
transposed_colors = list(map(list, zip(*combined_colors)))

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8*cm, 18*cm))

# Plot the colormap
# img = ax.imshow(combined_colors, aspect='auto', cmap='viridis')
img = ax.imshow(transposed_colors, aspect='auto', cmap='viridis')

# Set tick labels and tick positions
# cbar.set_ticks([0.5, 1.5, 2.5])
# cbar.set_ticklabels(['Silicon', 'Gallium', 'Vacancy'])

# Set labels for each row
ax.set_yticks(range(5))
ax.set_yticklabels(['90','70','50','30','10'])
ax.set_title('Legend', size = 22)
ax.set_xlabel('Impurity',size = 22)
ax.set_ylabel('Ga$^+$ Energy (keV)',size = 22)
ax.set_xticks(range(3))
ax.set_xticklabels(['V', 'Si', 'Ga'])
plt.tight_layout()
fig.savefig('legend.pdf', format= 'pdf')
