# %%
import numpy as np 
import matplotlib.pyplot as plt 
import uncertainties as unc
import pandas as pd
import uncertainties.unumpy as unp

# %%
SiO = pd.read_csv('SiO.csv')
SiN = pd.read_csv('SiN.csv')

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiO['DEPTH'], SiO['Ga'], '--k',label = 'Ga')
plt.plot(SiO['DEPTH'], SiO['C']*1e8, 'ob',label = 'Vacancy')
plt.plot(SiO['DEPTH'], SiO['Si'], '-r',label = 'Si')
plt.title('$SiO_2$')
plt.legend()

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiO['DEPTH'], SiO['C']*1e8, 'ob',label = 'Vacancy')
plt.title('$SiO_2$')
plt.legend()

# %%
def integrate(x, y):
    sum = 0
    for i in range(len(x)-1):
        sum += y[i]*(x[i+1]-x[i])
    return sum

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiO['DEPTH'], SiO['Ga'], '--k',label = 'Ga')
plt.plot(SiO['DEPTH'], SiO['Si'], '-r',label = 'Si')
plt.title('$SiO_2$')
plt.legend()

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiO['DEPTH'], SiO['Ga'], '--k',label = 'Ga')
plt.title('$SiO_2$')
plt.legend()

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiN['DEPTH'], SiN['Ga'], '--k',label = 'Ga')
plt.plot(SiN['DEPTH'][1:], SiN['C'][1:]*1e8, 'ob',label = 'Vacancy')
plt.plot(SiN['DEPTH'], SiN['Si'], '-r',label = 'Si')
plt.plot(SiN['DEPTH'], SiN['N'], '-g',label = 'N')
plt.title('$Si_3N_4$')
plt.legend()

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiN['DEPTH'], SiN['Ga'], '--k',label = 'Ga')
plt.plot(SiN['DEPTH'], SiN['Si'], '-r',label = 'Si')
plt.plot(SiN['DEPTH'], SiN['N'], '-g',label = 'N')
plt.title('$Si_3N_4$')
plt.legend()

# %%
plt.figure(figsize=(9,6.5))
plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density (cm-3/cm-2)')
plt.plot(SiN['DEPTH'], SiN['Ga'], '--k',label = 'Ga')
plt.title('$Si_3N_4$')
plt.legend()

# %%
integrate(np.array(SiO['DEPTH']), np.array(SiO['Si']))
# Out:
# 4551989.1000000015

# %%
integrate(np.array(SiN['DEPTH']), np.array(SiN['Si']))
# Out:
# 21757850.0

# %%
integrate(np.array(SiN['DEPTH']), np.array(SiN['N']))
# Out:
# 22016400.0
