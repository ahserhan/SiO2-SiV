# %%
import numpy as np 
import matplotlib.pyplot as plt 
import uncertainties as unc
import pandas as pd
import uncertainties.unumpy as unp
from matplotlib.cbook import get_sample_data

# %%
SiO = pd.read_csv('SiO.csv')
SiN = pd.read_csv('SiN.csv')
SiOfine = pd.read_csv('SiOfine.csv')
SiNfine = pd.read_csv('SiNfine.csv')

# %%
cm = 1/2.54
fig = plt.figure(figsize=(20*cm, 15*cm))
plt.rcParams.update({'font.size': 23})

# plt.rcParams.update({'font.size': 6})
# cm = 1/2.54 
# fig = plt.figure(figsize=(4.5*cm, 3.4*cm))
# plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
plt.ylabel(r'Density per Dose (cm$^{-3}$/cm$^{-2}$)')
plt.plot(SiO['DEPTH'], SiO['Ga'], '--k',label = 'Ga')
plt.plot(SiO['DEPTH'], SiO['C']*1e8, 'oC0',label = 'Vacancy')
plt.plot(SiOfine['DEPTH'], SiOfine['Si'], '-C2',label = 'Si',linewidth = 2)
plt.plot(SiOfine['DEPTH'], SiOfine['O'], '-C3',label = 'O',linewidth = 2)
plt.title('5 nm SiO$_2$')
# plt.legend()

a = plt.axes([0.57, .33, .37, .45])
# plt.grid()
plt.plot(SiO['DEPTH'], SiO['Ga'], '--k')
plt.plot(SiOfine['DEPTH'], SiOfine['Si'], '-C2',linewidth = 2.5)
plt.plot(SiOfine['DEPTH'], SiOfine['O'], '-C3',linewidth = 2.5)
plt.xlim([0,25])
plt.ylim([0,0.6e7])
# plt.title('Probability')
# plt.xticks([])
# plt.yticks([])

plt.plot([], '--k',label = 'Ga$^+$')
plt.plot([], 'oC0',label = 'Vacancy')
plt.plot([], '-C2',label = 'Si',linewidth = 2)
plt.plot([], '-C3',label = 'O',linewidth = 2)

lgd = plt.legend(loc = "upper right")
lgd.get_frame().set_alpha(0.1)
plt.tight_layout()
plt.savefig('sio.eps', format= 'eps',transparent=False)
# Out:
# C:\Users\56430\AppData\Local\Temp/ipykernel_25016/678448999.py:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
cm = 1/2.54
fig = plt.figure(figsize=(20*cm, 15*cm))
plt.rcParams.update({'font.size': 23})
# plt.rcParams.update({'font.size': 6})
# cm = 1/2.54 
# fig = plt.figure(figsize=(4.5*cm, 3.4*cm))

# plt.grid()
plt.xlabel(r'Depth in Diamond (nm)')
# plt.ylabel(r'Density per Dose (cm$^{-3}$/cm$^{-2}$)')
plt.ylabel(r'Density per Dose (cm$^{-3}$/cm$^{-2}$)')
plt.plot(SiN['DEPTH'], SiN['Ga'], '--k',label = 'Ga')
plt.plot(SiN['DEPTH'][1:], SiN['C'][1:]*1e8, 'oC0',label = 'Vacancy')
plt.plot(SiNfine['DEPTH'], SiNfine['Si'], '-C2',label = 'Si',linewidth = 2)
plt.plot(SiNfine['DEPTH'], SiNfine['N'], '-C1',label = 'N',linewidth = 2)
# plt.yticks([0,5e7,1e8,1.5e8,2e8],['','','','',''])
plt.title('5 nm SiN$_x$')
# plt.legend()

# a = plt.axes([0.51, .33, .37, .45])
a = plt.axes([0.57, .33, .37, .45])
# plt.grid()
plt.plot(SiN['DEPTH'], SiN['Ga'], '--k')
plt.plot(SiNfine['DEPTH'], SiNfine['Si'], '-C2',linewidth = 2.5)
plt.plot(SiNfine['DEPTH'], SiNfine['N'], '-C1',linewidth = 2.5)
plt.xlim([0,25])
plt.ylim([0,0.6e7])
# plt.xticks([])
plt.plot([], '--k',label = 'Ga$^+$')
plt.plot([], 'oC0',label = 'Vacancy')
plt.plot([], '-C2',label = 'Si',linewidth = 2)
plt.plot([], '-C1',label = 'N',linewidth = 2)

lgd = plt.legend(loc = "upper right")
lgd.get_frame().set_alpha(0.1)
plt.tight_layout()
plt.savefig('sin.eps', format= 'eps',transparent=False)
# Out:
# C:\Users\56430\AppData\Local\Temp/ipykernel_25016/2832923260.py:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
