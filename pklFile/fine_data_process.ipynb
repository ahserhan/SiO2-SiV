# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm

# %%
def findarg(data, value):
    arg = 0
    for wl in data:
        if wl<value:
            arg = arg + 1
        else:
            return arg
        
    return arg

# %%
data = pd.read_pickle('asher_20230526_fine_data.pkl')
im = data['im']
wavel = data['wavelength']
map = np.sum(im, axis = 2)
# pixel numbers x and y
px = len(im)
py = len(im[0])
intensity = np.zeros((px,py))
#total intensity plot
plt.imshow(map, cmap='viridis')
plt.colorbar()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# ### log scale plot

# %%
plt.imshow(map, cmap='viridis', norm =LogNorm(vmax = 2e6))
plt.colorbar()
plt.show()

# %% [markdown]
# # GR1 binning

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis',vmax = 6e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis',interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 5.4e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 5.2e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 5e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 4.8e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 4.6e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 4.5e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 4.4e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 739
binMax = 745
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', vmax = 4.35e4,interpolation='gaussian')
plt.colorbar()
plt.show()

# %% [markdown]
# # NV binning

# %%
#bin selection min and max
binMin = 630
binMax = 685
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', norm =LogNorm(vmax=4.05e5))
plt.colorbar()
plt.show()

# %%
#bin selection min and max
binMin = 630
binMax = 685
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', norm =LogNorm(vmax=4.05e5),interpolation='gaussian')
plt.colorbar()
plt.show()

# %% [markdown]
# # 2nd Raman Binning

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 13,20
binMin = 600
binMax = 620
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'][argmin:argmax],data['im'][regionx][regiony][argmin:argmax])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 17,6
binMin = 600
binMax = 620
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'][argmin:argmax],data['im'][regionx][regiony][argmin:argmax])

# %%
#bin selection min and max
binMin = 613
binMax = 614
argmin = findarg(wavel, binMin)
argmax = findarg(wavel, binMax)
#integrate over the bin
for i in range(px):
    for j in range(py):
        intensity[i][j] = im[i][j][argmin:argmax].sum()
#bin intensity plot
plt.figure(figsize=(12,9))
plt.imshow(intensity, cmap='viridis', norm =LogNorm(),interpolation='gaussian')
plt.colorbar()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# # data check

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 13,20

plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
#plot the spectra of the region of interste (x,y)
regionx, regiony = 17,6
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])

# %%
plt.figure(figsize=(12,9))
plt.plot(data['wavelength'],(data['im'][13][20]-data['im'][17][6]))
plt.grid()
plt.minorticks_on()

# %%
regionx, regiony = 23,3
plt.figure(figsize=(12,9))
plt.grid()
plt.minorticks_on()
plt.plot(data['wavelength'],data['im'][regionx][regiony])
