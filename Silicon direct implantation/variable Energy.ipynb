# %%
import numpy as np 
import matplotlib.pyplot as plt 
import uncertainties as unc
import pandas as pd
import uncertainties.unumpy as unp
from matplotlib import cm
import matplotlib.colors as col
from mpl_toolkits.mplot3d import Axes3D
from lmfit.models import ExponentialModel, GaussianModel

RANGE10 = pd.read_csv('RANGE10.csv')
RANGE30 = pd.read_csv('RANGE30.csv')
RANGE50 = pd.read_csv('RANGE50.csv')
RANGE70 = pd.read_csv('RANGE70.csv')
RANGE90 = pd.read_csv('RANGE90.csv')

VACANCY10 = pd.read_csv('VACANCY10.csv')
VACANCY30 = pd.read_csv('VACANCY30.csv')
VACANCY50 = pd.read_csv('VACANCY50.csv')
VACANCY70 = pd.read_csv('VACANCY70.csv')
VACANCY90 = pd.read_csv('VACANCY90.csv')

# %%
def plot3dSilicon(DEPTH,data,thickness,lab):
    if lab == 0:
        ax.plot(DEPTH, data, zs=thickness, zdir='y', lw = 1, color = 'r')
    else:
        ax.plot(DEPTH, data, zs=thickness, zdir='y', lw = 1, color = 'r', label = 'Silicon Ion Distribution')

# %%
def plot3dVacancy(DEPTH,data,thickness,lab):
    if lab == 0:
        ax.plot(DEPTH, data, zs=thickness, zdir='y',  color = 'b' )
    else:
        ax.plot(DEPTH, data, zs=thickness, zdir='y',  color = 'b',  label = 'Carbon Vacancy Distribution')

# %%
VACANCY10
# Out:
#      DEPTH     Si      C
# 0     4.01  0.130  0.383
# 1     8.01  0.163  0.485
# 2    12.00  0.172  0.595
# 3    16.00  0.182  0.681
# 4    20.00  0.190  0.760
# ..     ...    ...    ...
# 95  384.00  0.000  0.000
# 96  388.00  0.000  0.000
# 97  392.00  0.000  0.000
# 98  396.00  0.000  0.000
# 99  400.00  0.000  0.000
#
# [100 rows x 3 columns]

# %%
fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(projection='3d')
plt.grid()

ax.legend()
ax.set_xlim(0, 1750)
ax.set_ylim(0, 100)
ax.set_zlim(0, 1.2e6)
ax.set_xlabel('DEPTH in Diamond (nm)')
ax.set_ylabel('Focused-ion-beam Energy (keV)')
ax.set_zlabel('Density per Dose ($cm^{-3}$/$cm^{-2}$)')

plot3dSilicon(RANGE10['DEPTH'],RANGE10['Si'], 10,1)
plot3dSilicon(RANGE30['DEPTH'],RANGE30['Si'], 30,0)
plot3dSilicon(RANGE50['DEPTH'],RANGE50['Si'], 50,0)
plot3dSilicon(RANGE70['DEPTH'],RANGE70['Si'], 70,0)
plot3dSilicon(RANGE90['DEPTH'],RANGE90['Si'], 90,0)

ax.view_init(elev=15., azim=-80)

ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
ax.view_init(elev=20., azim=-55)

ax.legend()

fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(projection='3d')
plt.grid()

ax.legend()
ax.set_xlim(0, 1750)
ax.set_ylim(0, 100)
ax.set_zlim(0, 1e8)
ax.set_xlabel('DEPTH in Diamond (nm)')
ax.set_ylabel('Focused-ion-beam Energy (keV)')
ax.set_zlabel('Density per Dose ($cm^{-3}$/$cm^{-2}$)')

plot3dVacancy(VACANCY10['DEPTH'],VACANCY10['C']*1e8, 10,1)
plot3dVacancy(VACANCY30['DEPTH'],VACANCY30['C']*1e8, 30,0)
plot3dVacancy(VACANCY50['DEPTH'],VACANCY50['C']*1e8, 50,0)
plot3dVacancy(VACANCY70['DEPTH'],VACANCY70['C']*1e8, 70,0)
plot3dVacancy(VACANCY90['DEPTH'],VACANCY90['C']*1e8, 90,0)



ax.view_init(elev=20., azim=-80)

ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# def plot3dSilicon(DEPTH,data,thickness,lab):
#     model1 = GaussianModel() 
#     model = model1
#     params = model.make_params()

#     params['amplitude'].set(value = 2e8, vary=True)
#     params['center'].set(value = 0, vary=True)
#     params['sigma'].set(value = 7.5, vary=True)
#     model_fit = model.fit(data, params, x=DEPTH)
#     fit_x = np.linspace(0,np.array(DEPTH)[-1],1000)
#     fitcurve = model_fit.eval(model_fit.params, x = fit_x)
#     if lab == 0:
#         # ax.scatter(DEPTH, data, zs=thickness, zdir='y', marker = '^',  color = 'k', s = 5, )
#         ax.plot(fit_x, fitcurve, zs=thickness, zdir='y', linestyle = '--', lw = 1.3)
#     else:
#         # ax.scatter(DEPTH, data, zs=thickness, zdir='y', marker = '.', label = 'Carbon Vacancy Distribution Data', color = 'k', s = 1)
#         ax.plot(fit_x, fitcurve, zs=thickness, zdir='y', linestyle = '--', label = 'Silicon Ion Distribution', lw = 1.3)
    
#     obj = ax.fill_between(fit_x, 0, fitcurve, step='mid', alpha=0.1) 
#     ax.add_collection3d(obj, zs = thickness, zdir = 'y')

# %%
# def plot3dVacancy(DEPTH,data,thickness,lab):
#     model1 = GaussianModel() 
#     model = model1
#     params = model.make_params()

#     params['amplitude'].set(value = 2e8, vary=True)
#     params['center'].set(value = 0, vary=True)
#     params['sigma'].set(value = 7.5, vary=True)
#     model_fit = model.fit(data, params, x=DEPTH)
#     fit_x = np.linspace(0,np.array(DEPTH)[-1],1000)
#     fitcurve = model_fit.eval(model_fit.params, x = fit_x)
#     if lab == 0:
#         # ax.scatter(DEPTH, data, zs=thickness, zdir='y', marker = '^',  color = 'k', s = 5, )
#         ax.plot(fit_x, fitcurve, zs=thickness, zdir='y', linestyle = '--', lw = 1.3)
#     else:
#         # ax.scatter(DEPTH, data, zs=thickness, zdir='y', marker = '.', label = 'Carbon Vacancy Distribution Data', color = 'k', s = 1)
#         ax.plot(fit_x, fitcurve, zs=thickness, zdir='y', linestyle = '--', label = 'Carbon Vacancy Distribution', lw = 1.3)
    
#     obj = ax.fill_between(fit_x, 0, fitcurve, step='mid', alpha=0.1) 
#     ax.add_collection3d(obj, zs = thickness, zdir = 'y')

# %%
fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(projection='3d')
plt.grid()

ax.legend()
ax.set_xlim(0, 1600)
ax.set_ylim(0, 100)
ax.set_zlim(0, 1e8)
ax.set_xlabel('Depth in Diamond (nm)')
ax.set_ylabel('Focused-ion-beam Energy (keV)')
ax.set_zlabel('Density per Dose (cm$^{-3}$/cm$^{-2}$)')

plot3dSilicon(RANGE10['DEPTH'],RANGE10['Si'], 10,1)
plot3dSilicon(RANGE30['DEPTH'],RANGE30['Si'], 30,0)
plot3dSilicon(RANGE50['DEPTH'],RANGE50['Si'], 50,0)
plot3dSilicon(RANGE70['DEPTH'],RANGE70['Si'], 70,0)
plot3dSilicon(RANGE90['DEPTH'],RANGE90['Si'], 90,0)


plot3dVacancy(VACANCY10['DEPTH'],VACANCY10['C']*1e8, 10,1)
plot3dVacancy(VACANCY30['DEPTH'],VACANCY30['C']*1e8, 30,0)
plot3dVacancy(VACANCY50['DEPTH'],VACANCY50['C']*1e8, 50,0)
plot3dVacancy(VACANCY70['DEPTH'],VACANCY70['C']*1e8, 70,0)
plot3dVacancy(VACANCY90['DEPTH'],VACANCY90['C']*1e8, 90,0)



ax.view_init(elev=15., azim=-65)

ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(projection='3d')
plt.grid()

ax.legend()
ax.set_xlim(0, 1550)
ax.set_ylim(0, 100)
ax.set_zlim(0, 2.8e8)
ax.set_xlabel('Depth in Diamond (nm)')
ax.set_ylabel('Focused-ion-beam Energy (keV)')
ax.set_zlabel('Density per Dose (cm$^{-3}$/cm$^{-2}$)')

plot3dSilicon(RANGE10['DEPTH'],RANGE10['Si'], 10,1)
plot3dSilicon(RANGE30['DEPTH'],RANGE30['Si'], 30,0)
plot3dSilicon(RANGE50['DEPTH'],RANGE50['Si'], 50,0)
plot3dSilicon(RANGE70['DEPTH'],RANGE70['Si'], 70,0)
plot3dSilicon(RANGE90['DEPTH'],RANGE90['Si'], 90,0)


plot3dVacancy(VACANCY10['DEPTH'],VACANCY10['C']*1e8, 10,1)
plot3dVacancy(VACANCY30['DEPTH'],VACANCY30['C']*1e8, 30,0)
plot3dVacancy(VACANCY50['DEPTH'],VACANCY50['C']*1e8, 50,0)
plot3dVacancy(VACANCY70['DEPTH'],VACANCY70['C']*1e8, 70,0)
plot3dVacancy(VACANCY90['DEPTH'],VACANCY90['C']*1e8, 90,0)



ax.view_init(elev=20., azim=-55)

ax.legend()

fig.savefig("both.png", format="png",transparent=True)
fig.savefig("both.svg", format="svg",transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(projection='3d')


ax.legend()
ax.set_xlim(0, 1550)
ax.set_ylim(0, 100)
ax.set_zlim(0, 1.2e6)
# ax.set_xlabel('DEPTH in Diamond (nm)')
# ax.set_ylabel('Focused-ion-beam Energy (keV)')
# ax.set_zlabel('Density per Dose ($cm^{-3}$/$cm^{-2}$)')

plot3dSilicon(RANGE10['DEPTH'],RANGE10['Si'], 10,0)
plot3dSilicon(RANGE30['DEPTH'],RANGE30['Si'], 30,0)
plot3dSilicon(RANGE50['DEPTH'],RANGE50['Si'], 50,0)
plot3dSilicon(RANGE70['DEPTH'],RANGE70['Si'], 70,0)
plot3dSilicon(RANGE90['DEPTH'],RANGE90['Si'], 90,0)
ax.set_xticks([])
ax.set_yticks([])
# ax.set_zticks([])

ax.view_init(elev=20., azim=-55)
plt.savefig("si.png", format="png",transparent=True)
fig.savefig("si.svg", format="svg",transparent=True)
# Out:
# No handles with labels found to put in legend.
