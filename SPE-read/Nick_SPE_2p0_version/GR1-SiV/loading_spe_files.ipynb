# %%
# Imports all functions directly from load_spe.py
from load_spe import *

# %%
# This loads the .SPE file
b = load_SPE('before.SPE')
a = load_SPE('after.SPE')

# %%
# Print some parameters
print('Filename =', a.filename)
print('xdim =', a.xdim)
print('ydim =', a.ydim)
print('number of frames =', a.num_frames)


print('Filename =', b.filename)
print('xdim =', b.xdim)
print('ydim =', b.ydim)
print('number of frames =', b.num_frames)
# Out:
# Filename = after.SPE
# xdim = 4128
# ydim = 1
# number of frames = 1
# Filename = before.SPE
# xdim = 6951
# ydim = 1
# number of frames = 1

# %%
# Quick plot the data
a.quick_plot()
b.quick_plot()

# %% [markdown]
# If one wishes to process the data it is often desireable to manage the data directly.
# We demonstrate this in the following cells.

# %%
import matplotlib.pyplot as plt

# %%
# Get the wavelength and spectral data directly
xa = a.wavelength
ya = a.int

xb = b.wavelength
yb = b.int

# Plot it
plt.plot(xa,ya)
plt.plot(xb,yb)
plt.title('Manually accessing Spectrum data')
plt.show()

# %%
xa
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
ya
# Out:
# array([ 958,  967, 1011, ..., 1022, 1018, 1035], dtype=uint16)

# %%
test = load_SPE('test.SPE')
print('Filename =', test.filename)
print('xdim =', test.xdim)
print('ydim =', test.ydim)
print('number of frames =', test.num_frames)
# Out:
# Filename = test.SPE
# xdim = 4128
# ydim = 1
# number of frames = 1

# %%
test.SPE_version
# Out:
# 3.0
